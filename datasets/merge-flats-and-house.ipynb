# %%
import numpy as np
import pandas as pd

# %%
flats = pd.read_csv('kp_flats_cleaned.csv')
houses = pd.read_csv('kp_house_cleaned.csv')

# %%
df = pd.concat([flats,houses],ignore_index=True)

# %%
df = df.sample(df.shape[0],ignore_index=True)

# %%
df.head()
# Out:
#                       property_name property_type  \
# 0  3 BHK Flat in Sector 109 Gurgaon          flat
# 1   4 BHK Flat in Sector 86 Gurgaon          flat
# 2   4 BHK Flat in Sector 56 Gurgaon          flat
# 3               3 BHK Flat in Sohna          flat
# 4  4 BHK Flat in Sector 112 Gurgaon          flat
#
#                        society  price  price_per_sqft    area  \
# 0  brisk lumbini terrace homes   1.38          6338.0  2177.0
# 1         dlf new town heights   1.55          6578.0  2356.0
# 2               the lions cghs   2.05          7884.0  2600.0
# 3              eldeco accolade   1.14          6530.0  1746.0
# 4          experion windchants   5.60         11551.0  4848.0
#
#                                         areaWithType  bedRoom  bathroom  \
# 0                   Carpet area: 2177 (202.25 sq.m.)        3         3
# 1  Super Built up area 2356(218.88 sq.m.)Carpet a...        4         4
# ...

# %%
df.to_csv('kp_gurgaon_properties.csv',index=False)

# %%
df1 = pd.read_csv('kp_gurgaon_properties.csv')
df1.head()
# Out:
#                       property_name property_type  \
# 0  3 BHK Flat in Sector 109 Gurgaon          flat
# 1   4 BHK Flat in Sector 86 Gurgaon          flat
# 2   4 BHK Flat in Sector 56 Gurgaon          flat
# 3               3 BHK Flat in Sohna          flat
# 4  4 BHK Flat in Sector 112 Gurgaon          flat
#
#                        society  price  price_per_sqft    area  \
# 0  brisk lumbini terrace homes   1.38          6338.0  2177.0
# 1         dlf new town heights   1.55          6578.0  2356.0
# 2               the lions cghs   2.05          7884.0  2600.0
# 3              eldeco accolade   1.14          6530.0  1746.0
# 4          experion windchants   5.60         11551.0  4848.0
#
#                                         areaWithType  bedRoom  bathroom  \
# 0                   Carpet area: 2177 (202.25 sq.m.)        3         3
# 1  Super Built up area 2356(218.88 sq.m.)Carpet a...        4         4
# ...

# %%
df1.shape
# Out:
# (3961, 20)

# %%
df2 = pd.read_csv('kp_gurgaon_properties.csv')
df2.head()
# Out:
#                       property_name property_type  \
# 0  3 BHK Flat in Sector 109 Gurgaon          flat
# 1   4 BHK Flat in Sector 86 Gurgaon          flat
# 2   4 BHK Flat in Sector 56 Gurgaon          flat
# 3               3 BHK Flat in Sohna          flat
# 4  4 BHK Flat in Sector 112 Gurgaon          flat
#
#                        society  price  price_per_sqft    area  \
# 0  brisk lumbini terrace homes   1.38          6338.0  2177.0
# 1         dlf new town heights   1.55          6578.0  2356.0
# 2               the lions cghs   2.05          7884.0  2600.0
# 3              eldeco accolade   1.14          6530.0  1746.0
# 4          experion windchants   5.60         11551.0  4848.0
#
#                                         areaWithType  bedRoom  bathroom  \
# 0                   Carpet area: 2177 (202.25 sq.m.)        3         3
# 1  Super Built up area 2356(218.88 sq.m.)Carpet a...        4         4
# ...

# %%
df2.shape
# Out:
# (3961, 20)
